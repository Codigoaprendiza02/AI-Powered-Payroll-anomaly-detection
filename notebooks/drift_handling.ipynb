# %% [markdown]
# # Drift Handling
#
# In this notebook the target is to detect, monitor and retrain following types of drift occuring in the payroll data:
# 1. Concept Drift
# 2. Data Drift
#
# using batch pipeline and real-time pipeline.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
refined_data = pd.read_csv("../data/refined_data.csv")
refined_data.head()
# Out:
#    employee_id employee_name department   designation  base_salary  \
# 0         1001         Aarav         IT     Developer        50000
# 1         1002          Diya         HR  HR Executive        35000
# 2         1003         Rohan    Finance    Accountant        40000
# 3         1004         Sneha         IT     Developer        55000
# 4         1005         Karan      Sales    Sales Exec        30000
#
#   joining_date  working_days  present_days  overtime_hours  gross_salary  ...  \
# 0   2023-01-31            22            20               5         52500  ...
# 1   2023-02-28            22            21               2         36000  ...
# 2   2023-03-31            22            19               0         40000  ...
# 3   2023-04-30            22            22               8         59000  ...
# 4   2023-05-31            22            20               4         32000  ...
#
#    salary_if_score_norm  deduction_if_score_norm  overtime_if_score_norm  \
# ...
